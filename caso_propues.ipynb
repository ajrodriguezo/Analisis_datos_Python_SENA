# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Importar datos

df = pd.read_csv('Data_Caso_Propuesto.csv')
df.head()
# Out:
#    Codigo    Ciudad     Departamento             Barrio  \
# 0   17180    BOGOTA     CUNDINAMARCA                NaN
# 1   19292    BOGOTA     CUNDINAMARCA                NaN
# 2   19292    BOGOTA     CUNDINAMARCA                NaN
# 3    2575  SOGAMOSO           BOYACÁ             CENTRO
# 4   11409      BUGA  VALLE DEL CAUCA  VEREDA CHAMBIMBAL
#
#                                            Direccion  Area Terreno  \
# 0                          AV CR 7 NO. 166 - 51 LT B          0.00
# 1                                  CL 72 No. 12 - 77          0.00
# 2                                  CL 72 No. 12 - 77          0.00
# 3  CRA. 10 #11- 78/80 Ó CL 12 # 9 - 77/85 Ó CALLE...       1655.08
# 4  LT A1-A24 B1-B79 C1-C51 D1-D9 STA ROSA LT1-46 ...    3217197.00
#
#    Area Construida            Detalle Disponibilidad    Estrato        Precio  \
# 0              0.0   COMERCIALIZABLE CON RESTRICCION       TRES  2.958081e+10
# ...

# %%
df.describe(include='all')
# Out:
#               Codigo         Ciudad Departamento          Barrio  \
# count     463.000000            463          463              40
# unique           NaN             43           14              17
# top              NaN  VILLAVICENCIO         META  VEREDA PALERMO
# freq             NaN            290          292              10
# mean    18003.151188            NaN          NaN             NaN
# std      1992.191499            NaN          NaN             NaN
# min      2575.000000            NaN          NaN             NaN
# 25%     18184.500000            NaN          NaN             NaN
# 50%     18332.000000            NaN          NaN             NaN
# 75%     18539.500000            NaN          NaN             NaN
# max     19344.000000            NaN          NaN             NaN
#
#                                                 Direccion  Area Terreno  \
# count                                                 463  4.630000e+02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Codigo                  463 non-null    int64
#  1   Ciudad                  463 non-null    object
#  2   Departamento            463 non-null    object
#  3   Barrio                  40 non-null     object
#  4   Direccion               463 non-null    object
#  5   Area Terreno            463 non-null    float64
#  6   Area Construida         463 non-null    float64
#  7   Detalle Disponibilidad  463 non-null    object
#  8   Estrato                 463 non-null    object
#  9   Precio                  463 non-null    float64
#  10  Tipo de Inmueble        463 non-null    object
#  11  Datos Adicionales       118 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 43.5+ KB

# %%
df.isnull().sum()
# Out:
# Codigo                      0
# Ciudad                      0
# Departamento                0
# Barrio                    423
# Direccion                   0
# Area Terreno                0
# Area Construida             0
# Detalle Disponibilidad      0
# Estrato                     0
# Precio                      0
# Tipo de Inmueble            0
# Datos Adicionales         345
# dtype: int64

# %%
# Saber si existen elementos duplicados
df.duplicated().sum()
# Out:
# 0

# %%
##
## Segun el  tipo de immuble como influye en el precio del inmueble
##

# %%
# al ver que son tatos datos nulos y que su eliminacion nos dejaria sin datos para el rpocesamiento
# vamos aproceder a reemplaar estos datos por variables cualquieras y no seran tenido en cuenta
# o se se eliminaran las columnas para que no afecten el calculo

# Vamos a elimnar las columnas Barrio y Datos Adicionales 

df = df.drop(['Datos Adicionales','Barrio'],axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Codigo                  463 non-null    int64
#  1   Ciudad                  463 non-null    object
#  2   Departamento            463 non-null    object
#  3   Direccion               463 non-null    object
#  4   Area Terreno            463 non-null    float64
#  5   Area Construida         463 non-null    float64
#  6   Detalle Disponibilidad  463 non-null    object
#  7   Estrato                 463 non-null    object
#  8   Precio                  463 non-null    float64
#  9   Tipo de Inmueble        463 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 36.3+ KB

# %%
df.describe()
# Out:
#              Codigo  Area Terreno  Area Construida        Precio
# count    463.000000  4.630000e+02       463.000000  4.630000e+02
# mean   18003.151188  1.515204e+04        87.517279  6.672032e+08
# std     1992.191499  1.827101e+05      1137.469077  3.272992e+09
# min     2575.000000  0.000000e+00         0.000000  4.650000e+06
# 25%    18184.500000  0.000000e+00         0.000000  1.230500e+07
# 50%    18332.000000  0.000000e+00         0.000000  1.587000e+07
# 75%    18539.500000  0.000000e+00         0.000000  1.379955e+08
# max    19344.000000  3.217197e+06     22724.000000  4.523379e+10

# %%
numero = "4.523379e+10"
numero_entero = int(float(numero))
print(numero_entero)
# Out:
# 45233790000

# %%
df.describe(include='all')
# Out:
#               Codigo         Ciudad Departamento  \
# count     463.000000            463          463
# unique           NaN             43           14
# top              NaN  VILLAVICENCIO         META
# freq             NaN            290          292
# mean    18003.151188            NaN          NaN
# std      1992.191499            NaN          NaN
# min      2575.000000            NaN          NaN
# 25%     18184.500000            NaN          NaN
# 50%     18332.000000            NaN          NaN
# 75%     18539.500000            NaN          NaN
# max     19344.000000            NaN          NaN
#
#                                                 Direccion  Area Terreno  \
# count                                                 463  4.630000e+02
# unique                                                456           NaN
# top     CR 51 B No. 76-136 ED CENTRO EMPRESARIAL LA PR...           NaN
# freq                                                    2           NaN
# ...

# %%
precio_estrato = df['Precio'].groupby(df['Estrato']).count()
precio_estrato.plot.pie(autopct='%.1f%%')
# Out:
# <Axes: ylabel='Precio'>

# %%
Precio_tipo = sns.boxplot(x=df["Tipo de Inmueble"], y=df["Precio"])
Precio_tipo.set_xticklabels(Precio_tipo.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'LOTE COMERCIAL'),
#  Text(1, 0, 'EDIFICIO'),
#  Text(2, 0, 'CLINICA'),
#  Text(3, 0, 'LOTE MIXTO'),
#  Text(4, 0, 'LOTE CON CONSTRUCCION'),
#  Text(5, 0, 'HOTEL'),
#  Text(6, 0, 'BODEGA'),
#  Text(7, 0, 'APARTAMENTO'),
#  Text(8, 0, 'LOTE VIVIENDA'),
#  Text(9, 0, 'FINCA'),
#  Text(10, 0, 'EDIFICIO OFICINAS'),
#  Text(11, 0, 'CASA'),
#  Text(12, 0, 'LOCAL'),
#  Text(13, 0, 'LOTE INDUSTRIAL'),
#  Text(14, 0, 'LOTE'),
#  Text(15, 0, 'OFICINA'),
#  Text(16, 0, 'GARAJE'),
#  Text(17, 0, 'DEPOSITO'),
#  Text(18, 0, 'LOTE AGRICOLA')]

# %%
plt.figure(figsize=(20,10))
plot2 = sns.countplot(data = df, x='Tipo de Inmueble')
plot2.set_xticklabels(plot2.get_xticklabels(), rotation=90)
plt.show()

# %%
plot3 = df['Tipo de Inmueble'].groupby(df['Tipo de Inmueble']).count()
plot3.plot.pie(autopct='%.1f%%')
# Out:
# <Axes: ylabel='Tipo de Inmueble'>

# %%
df['Tipo de Inmueble'].describe()
# Out:
# count       463
# unique       19
# top       LOCAL
# freq        305
# Name: Tipo de Inmueble, dtype: object

# %%
data_encoded = pd.get_dummies(df, columns=['Tipo de Inmueble'])

data_encoded['Tipo de Inmueble_LOCAL'].corr(df['Precio'])
# Out:
# -0.2713467118532538

# %%
data_encoded['Tipo de Inmueble_LOTE MIXTO'].corr(df['Precio'])
# Out:
# 0.37600989339365154
